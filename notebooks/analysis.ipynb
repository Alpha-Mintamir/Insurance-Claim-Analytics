# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../scripts')))

# %%
from utils import *
from plottings import *

# %%
df = pd.read_csv('../data/MachineLearningRating_v3.txt', delimiter='|')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15156\1487130439.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/MachineLearningRating_v3.txt', delimiter='|')

# %% [markdown]
# # Explanatory Data Analysis

# %% [markdown]
# ## 1. Understanding the Data

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# 0  Current account  ...             Mobility - Windscreen    Windscreen
# 1  Current account  ...             Mobility - Windscreen    Windscreen
# 2  Current account  ...             Mobility - Windscreen    Windscreen
# 3  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
# 4  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
#
#     CoverType            CoverGroup              Section  \
# 0  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3  Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4  Own Damage  Comprehensive - Taxi  Motor Comprehensive
#
#                            Product StatutoryClass StatutoryRiskType  \
# 0  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 1  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 2  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 3  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 4  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
#
#    TotalPremium TotalClaims
# 0     21.929825         0.0
# 1     21.929825         0.0
# 2      0.000000         0.0
# 3    512.848070         0.0
# 4      0.000000         0.0
#
# [5 rows x 52 columns]

# %%
df.tail()
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
#         Citizenship   LegalType Title Language       Bank      AccountType  \
# 1000093          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000094          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000095          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000096          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000097          ZW  Individual    Mr  English  ABSA Bank  Savings account
#
#          ... ExcessSelected        CoverCategory            CoverType  \
# 1000093  ...      No excess          Third Party          Third Party
# 1000094  ...      No excess          Third Party          Third Party
# 1000095  ...      No excess          Third Party          Third Party
# 1000096  ...      No excess  Passenger Liability  Passenger Liability
# 1000097  ...      No excess  Passenger Liability  Passenger Liability
#
#                    CoverGroup              Section  \
# 1000093  Comprehensive - Taxi  Motor Comprehensive
# 1000094  Comprehensive - Taxi  Motor Comprehensive
# 1000095  Comprehensive - Taxi  Motor Comprehensive
# 1000096  Comprehensive - Taxi  Motor Comprehensive
# 1000097  Comprehensive - Taxi  Motor Comprehensive
#
#                                     Product StatutoryClass StatutoryRiskType  \
# 1000093  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
# 1000094  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
# 1000095  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
# 1000096  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
# 1000097  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
#
#          TotalPremium TotalClaims
# 1000093    347.235175         0.0
# 1000094    347.235175         0.0
# 1000095    347.235175         0.0
# 1000096      2.315000         0.0
# 1000097      2.315000         0.0
#
# [5 rows x 52 columns]

# %%
df.shape
# Out:
# (1000098, 52)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
#  13  Province                  1000098 non-null  object
#  14  PostalCode                1000098 non-null  int64
#  15  MainCrestaZone            1000098 non-null  object
#  16  SubCrestaZone             1000098 non-null  object
#  17  ItemType                  1000098 non-null  object
#  18  mmcode                    999546 non-null   float64
#  19  VehicleType               999546 non-null   object
#  20  RegistrationYear          1000098 non-null  int64
#  21  make                      999546 non-null   object
#  22  Model                     999546 non-null   object
#  23  Cylinders                 999546 non-null   float64
#  24  cubiccapacity             999546 non-null   float64
#  25  kilowatts                 999546 non-null   float64
#  26  bodytype                  999546 non-null   object
#  27  NumberOfDoors             999546 non-null   float64
#  28  VehicleIntroDate          999546 non-null   object
#  29  CustomValueEstimate       220456 non-null   float64
#  30  AlarmImmobiliser          1000098 non-null  object
#  31  TrackingDevice            1000098 non-null  object
#  32  CapitalOutstanding        1000096 non-null  object
#  33  NewVehicle                846803 non-null   object
#  34  WrittenOff                358197 non-null   object
#  35  Rebuilt                   358197 non-null   object
#  36  Converted                 358197 non-null   object
#  37  CrossBorder               698 non-null      object
#  38  NumberOfVehiclesInFleet   0 non-null        float64
#  39  SumInsured                1000098 non-null  float64
#  40  TermFrequency             1000098 non-null  object
#  41  CalculatedPremiumPerTerm  1000098 non-null  float64
#  42  ExcessSelected            1000098 non-null  object
#  43  CoverCategory             1000098 non-null  object
#  44  CoverType                 1000098 non-null  object
#  45  CoverGroup                1000098 non-null  object
#  46  Section                   1000098 non-null  object
#  47  Product                   1000098 non-null  object
#  48  StatutoryClass            1000098 non-null  object
#  49  StatutoryRiskType         1000098 non-null  object
#  50  TotalPremium              1000098 non-null  float64
#  51  TotalClaims               1000098 non-null  float64
# dtypes: bool(1), float64(11), int64(4), object(36)
# memory usage: 390.1+ MB

# %%
df.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
df.CoverCategory.value_counts()
# Out:
# CoverCategory
# Passenger Liability                                    104158
# Third Party                                            102825
# Keys and Alarms                                        102428
# Signage and Vehicle Wraps                              102416
# Emergency Charges                                      102416
# Cleaning and Removal of Accident Debris                102414
# Windscreen                                              97313
# Own Damage                                              78981
# Income Protector                                        60001
# Basic Excess Waiver                                     53755
# Accidental Death                                        27321
# Credit Protection                                       18070
# Own Damage.                                             15095
# Own damage                                               8776
# Windscreen (2015)                                        6450
# Income Protector (2015)                                  4812
# Basic Excess Waiver (2015)                               4014
# Roadside Assistance                                      3834
# Vehicle over R100 000                                    1552
# Deposit Cover                                            1299
# Asset Value Preserver                                     865
# Standalone passenger liability                            544
# Cash Takings                                              291
# Baggage/Luggage                                           172
# Vehicle under R100 000                                    154
# Trailer                                                    76
# Third Party Only                                           63
# Factory Fitted Sound and Other Electronic Equipment         3
# Name: count, dtype: int64

# %%
df.CapitalOutstanding.value_counts()
# Out:
# CapitalOutstanding
# 0           665918
# 0           122199
# 0.00          4663
# 232500        3285
# 329500        3244
#              ...
# 196300           2
# 337000           2
# 281600           2
# 246200.0         1
# 293900.0         1
# Name: count, Length: 1011, dtype: int64

# %%
df[['TotalClaims', 'TotalPremium']].describe()
# Out:
#         TotalClaims  TotalPremium
# count  1.000098e+06  1.000098e+06
# mean   6.486119e+01  6.190550e+01
# std    2.384075e+03  2.302845e+02
# min   -1.200241e+04 -7.825768e+02
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  2.178333e+00
# 75%    0.000000e+00  2.192982e+01
# max    3.930921e+05  6.528260e+04

# %% [markdown]
# ## 2. Missing values and filling them

# %% [markdown]
# ### missing values

# %%
missing_values_table(df)
# Out:
# Your selected dataframe has 52 columns.
# There are 22 columns that have missing values.
#                          Missing Values  % of Total Values
# NumberOfVehiclesInFleet         1000098              100.0
# CrossBorder                      999400               99.9
# CustomValueEstimate              779642               78.0
# Converted                        641901               64.2
# Rebuilt                          641901               64.2
# WrittenOff                       641901               64.2
# NewVehicle                       153295               15.3
# Bank                             145961               14.6
# AccountType                       40232                4.0
# Gender                             9536                1.0
# MaritalStatus                      8259                0.8
# Cylinders                           552                0.1
# cubiccapacity                       552                0.1
# kilowatts                           552                0.1
# NumberOfDoors                       552                0.1
# VehicleIntroDate                    552                0.1
# Model                               552                0.1
# make                                552                0.1
# VehicleType                         552                0.1
# mmcode                              552                0.1
# bodytype                            552                0.1
# CapitalOutstanding                    2                0.0

# %% [markdown]
# ### Since over 99% of users are from South Africa ('ZA'), and the company is based there, empty citizenship values were replaced with 'ZA'.

# %%
# Replace NaN, empty strings, or whitespace-only strings with 'ZA'
df['Citizenship'] = df['Citizenship'].apply(lambda x: 'ZA' if pd.isna(x) or x.strip() == '' else x)

# %% [markdown]
# ### The columns 'mmcode', 'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders', 'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors', 'VehicleIntroDate' all have the same 552 null values, indicating a correlation. Dropping one column from this group can resolve the missing data issue.

# %%
df.dropna(subset=['mmcode'], inplace=True)

# %% [markdown]
# ### Gender and Maritialstatus columns' null values replaced by "Not Specified" and missing Bank column replaced by "unknown".

# %%
df.MaritalStatus.fillna('Not specified', inplace=True)
df.Gender.fillna('Not specified', inplace=True)
df.AccountType.fillna('Not specified', inplace=True)
df.Bank.fillna('Unknown', inplace=True)

# %% [markdown]
# ### NumberOfVehiclesInFleet, CrossBorder and CustomValueEstimate columns are dropped due to high number of missing values(100, 99 and 78%).

# %%
df.drop(['NumberOfVehiclesInFleet','CrossBorder', 'CustomValueEstimate' ], axis=1, inplace=True)

# %% [markdown]
# ### WrittenOff, Rebuilt and Converted have equal percentage of missing values, indicating a correlation. As they are categorical columns, the missing values are replaced with Mode value, which is "No" for all three columns. And NewVehicle column replaced with mode value, More than 6 months

# %%
df.WrittenOff.fillna('No', inplace=True)
df.Rebuilt.fillna('No', inplace=True)
df.Converted.fillna('No', inplace=True)
df.NewVehicle.fillna('More than 6 months', inplace=True)

# %% [markdown]
# ### CapitalOutstanding column has 2 missing values, which are replaced with the mean value of the column.

# %%
df['CapitalOutstanding'] = pd.to_numeric(df['CapitalOutstanding'], errors='coerce')
df['CapitalOutstanding'].fillna(df['CapitalOutstanding'].mean(), inplace=True)

# %% [markdown]
# ### Missing Values after the 'missing value operations'

# %%
missing_values_table(df)
# Out:
# Your selected dataframe has 49 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %% [markdown]
# ## 3. Date columns

# %% [markdown]
# ## VehicleIntroDate and TransactionMonth columns are converted to datetime format.

# %%
df['VehicleIntroDate'] = pd.to_datetime(df['VehicleIntroDate'], format='%m/%Y', errors='coerce')

# %%
# Convert to datetime
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])

# Format to MM/YYYY
df['TransactionMonthFormatted'] = df['TransactionMonth'].dt.to_period('M')

# %% [markdown]
# ## 4. Outliers Detection and Handling

# %% [markdown]
# ### detection of outliers in key columns, TotalClaim and TotalPremium

# %%
outlier_columns = ['TotalClaims', 'TotalPremium']
Outliers_detected = detect_outliers(df,outlier_columns)
print(Outliers_detected)
# Out:
# {'TotalClaims': [1560, 1779, 2601, 3111, 3220, 3366, 5291, 6546, 6662, 7510, 8857, 9934, 10751, 13017, 13137, 13169, 13636, 13697, 13701, 14226, 15404, 17231, 18957, 19197, 20831, 20869, 21161, 21429, 22232, 22280, 25247, 25844, 25952, 28878, 30907, 31024, 31032, 32425, 32968, 33215, 33796, 33981, 34525, 34947, 35003, 35062, 35159, 37794, 38213, 38476, 38508, 39635, 40842, 41854, 42208, 42552, 43871, 45354, 45753, 46128, 47231, 47575, 49040, 49319, 49887, 50216, 50846, 51334, 51780, 51829, 52919, 53135, 55021, 55377, 55390, 56632, 57253, 57973, 57975, 58530, 59190, 59498, 59499, 59745, 59812, 59852, 60203, 60551, 61548, 62068, 62417, 62605, 62620, 62781, 62970, 65583, 65988, 66346, 68384, 68780, 68824, 71023, 72194, 72208, 73252, 74170, 74235, 74501, 75238, 75285, 75800, 77016, 77279, 77485, 77614, 77681, 77778, 78049, 78232, 78364, 78637, 78638, 78970, 79520, 79588, 79823, 79997, 80380, 81235, 81333, 81382, 81423, 82723, 84213, 84299, 85270, 86369, 87205, 87724, 89451, 89924, 90674, 91718, 92376, 93012, 93791, 94923, 96350, 98488, 98788, 99141, 99473, 102683, 106160, 107252, 107695, 107698, 109905, 110720, 110778, 111562, 111909, 112046, 112570, 112646, 112931, 114711, 114809, 115856, 116764, 116924, 117552, 118202, 118517, 119117, 122024, 122147, 122226, 123718, 123871, 124303, 124888, 124940, 127075, 127223, 127436, 127626, 127871, 128029, 128597, 129107, 129483, 130344, 130372, 131180, 131853, 131878, 132743, 133634, 133987, 134513, 134840, 135755, 135961, 136081, 136383, 136885, 137456, 137465, 138428, 138680, 139896, 140088, 141173, 142765, 143032, 143247, 143290, 144075, 145230, 146510, 147123, 147362, 149178, 149510, 152749, 154354, 154926, 155117, 155358, 156880, 157746, 157857, 158489, 158981, 159107, 159616, 159791, 160547, 162694, 163936, 164155, 165285, 165814, 166242, 167247, 168075, 168816, 169009, 169440, 169446, 169551, 169646, 170324, 171290, 171720, 172703, 172766, 173451, 173586, 174055, 175374, 176337, 177152, 179436, 179852, 180275, 181980, 183223, 186264, 187637, 188609, 189630, 190127, 191257, 191285, 193010, 193457, 193550, 193977, 194881, 196376, 198395, 198864, 199923, 199943, 201380, 201943, 202196, 202319, 203863, 207525, 207638, 208123, 208189, 208242, 208388, 208775, 209278, 210739, 210786, 210906, 210993, 211960, 213965, 214058, 215208, 215242, 215452, 216074, 216116, 218418, 219035, 219372, 219423, 219809, 220773, 223702, 223704, 225224, 225534, 226513, 226999, 228118, 228135, 229534, 229567, 233489, 233887, 234118, 234130, 235571, 236256, 236964, 237458, 238708, 239418, 240347, 241024, 241226, 241519, 242293, 243495, 243521, 243541, 243911, 244486, 244796, 248161, 248236, 248462, 249501, 249684, 249795, 250564, 250746, 252078, 252879, 254366, 255365, 255959, 255961, 257893, 258987, 261034, 261189, 262584, 263310, 263496, 264146, 264616, 265277, 266034, 266389, 267278, 267324, 267351, 267532, 268681, 268744, 268987, 269169, 270654, 271107, 271248, 272383, 272777, 272956, 277466, 278624, 278816, 279841, 280683, 281696, 281861, 282342, 282856, 282935, 283334, 283389, 283575, 285027, 286176, 286265, 289199, 290557, 290609, 292730, 293297, 293519, 293609, 294116, 294782, 295379, 297117, 297546, 298130, 298368, 299030, 299631, 299846, 299927, 299971, 300260, 300848, 302154, 302910, 302951, 303381, 303490, 303656, 304426, 304682, 305325, 306167, 306225, 307441, 308486, 310151, 310289, 310568, 312289, 313175, 313669, 313947, 314020, 315471, 315834, 316000, 316361, 316363, 317247, 317708, 318902, 318908, 319970, 321126, 321914, 321922, 322626, 323561, 324126, 324668, 325406, 325479, 325839, 326560, 327746, 330241, 330453, 330494, 330504, 330589, 332368, 333488, 334064, 334468, 334569, 334690, 334859, 336982, 337085, 337199, 337374, 337665, 337877, 338239, 340524, 341113, 341318, 341489, 341492, 341555, 342729, 343421, 344584, 344653, 344665, 345700, 345817, 348207, 348827, 348829, 350009, 350114, 350205, 351659, 352261, 353978, 354724, 354855, 355012, 355277, 355324, 355504, 356353, 356444, 357235, 358 ...

# %% [markdown]
# ### Fixing the outliers in TotalClaim and TotalPremium columns

# %%
fix_outlier(df, outlier_columns)
# Out:
#          UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0                     145249     12827       2015-03-01             True
# 1                     145249     12827       2015-05-01             True
# 2                     145249     12827       2015-07-01             True
# 3                     145255     12827       2015-05-01             True
# 4                     145255     12827       2015-07-01             True
# ...                      ...       ...              ...              ...
# 1000093                31520       389       2015-04-01            False
# 1000094                31520       389       2015-06-01            False
# 1000095                31520       389       2015-08-01            False
# 1000096                31519       389       2014-07-01            False
# 1000097                31519       389       2015-02-01            False
#
#         Citizenship          LegalType Title Language                 Bank  \
# 0                ZA  Close Corporation    Mr  English  First National Bank
# 1                ZA  Close Corporation    Mr  English  First National Bank
# 2                ZA  Close Corporation    Mr  English  First National Bank
# 3                ZA  Close Corporation    Mr  English  First National Bank
# 4                ZA  Close Corporation    Mr  English  First National Bank
# ...             ...                ...   ...      ...                  ...
# 1000093          ZW         Individual    Mr  English            ABSA Bank
# 1000094          ZW         Individual    Mr  English            ABSA Bank
# 1000095          ZW         Individual    Mr  English            ABSA Bank
# 1000096          ZW         Individual    Mr  English            ABSA Bank
# 1000097          ZW         Individual    Mr  English            ABSA Bank
#
#              AccountType  ...        CoverCategory            CoverType  \
# 0        Current account  ...           Windscreen           Windscreen
# 1        Current account  ...           Windscreen           Windscreen
# 2        Current account  ...           Windscreen           Windscreen
# 3        Current account  ...           Own damage           Own Damage
# 4        Current account  ...           Own damage           Own Damage
# ...                  ...  ...                  ...                  ...
# 1000093  Savings account  ...          Third Party          Third Party
# 1000094  Savings account  ...          Third Party          Third Party
# 1000095  Savings account  ...          Third Party          Third Party
# 1000096  Savings account  ...  Passenger Liability  Passenger Liability
# 1000097  Savings account  ...  Passenger Liability  Passenger Liability
#
#                    CoverGroup              Section  \
# 0        Comprehensive - Taxi  Motor Comprehensive
# 1        Comprehensive - Taxi  Motor Comprehensive
# 2        Comprehensive - Taxi  Motor Comprehensive
# 3        Comprehensive - Taxi  Motor Comprehensive
# 4        Comprehensive - Taxi  Motor Comprehensive
# ...                       ...                  ...
# 1000093  Comprehensive - Taxi  Motor Comprehensive
# 1000094  Comprehensive - Taxi  Motor Comprehensive
# 1000095  Comprehensive - Taxi  Motor Comprehensive
# 1000096  Comprehensive - Taxi  Motor Comprehensive
# 1000097  Comprehensive - Taxi  Motor Comprehensive
#
#                                     Product StatutoryClass StatutoryRiskType  \
# 0           Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 1           Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 2           Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 3           Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 4           Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# ...                                     ...            ...               ...
# 1000093  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
# 1000094  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
# 1000095  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
# 1000096  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
# 1000097  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
#
#         TotalPremium  TotalClaims TransactionMonthFormatted
# 0          21.929825          0.0                   2015-03
# 1          21.929825          0.0                   2015-05
# 2           0.000000          0.0                   2015-07
# 3         404.922544          0.0                   2015-05
# 4           0.000000          0.0                   2015-07
# ...              ...          ...                       ...
# 1000093   347.235175          0.0                   2015-04
# 1000094   347.235175          0.0                   2015-06
# 1000095   347.235175          0.0                   2015-08
# 1000096     2.315000          0.0                   2014-07
# 1000097     2.315000          0.0                   2015-02
#
# [999546 rows x 50 columns]

# %% [markdown]
# ## 5. Univariate Analysis

# %% [markdown]
# ### Histograms for numerical columns

# %%
univariate_num_columns = ['TotalPremium','TotalClaims','CalculatedPremiumPerTerm', 'CapitalOutstanding']
plot_histograms(df, univariate_num_columns)
# Out:
# c:\Insurance-Claim-Analytics\venv\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Insurance-Claim-Analytics\venv\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### bar charts for categorical columns

# %%
univariate_cat_columns = ['IsVATRegistered', 'LegalType','Title', 'Bank','Gender','VehicleType', 'TrackingDevice', 'NewVehicle', 'Rebuilt', 'CoverCategory', 'CoverGroup', 'ExcessSelected']
plot_bar_charts(df, univariate_cat_columns)

# %% [markdown]
# # Data Version Control
